# %% [markdown]
# <div style="width: 100%; clear: both;">
# <div style="float: left; width: 50%;">
# <img src="http://www.uoc.edu/portal/_resources/common/imatges/marca_UOC/UOC_Masterbrand.jpg", align="left">
# </div>
# <div style="float: right; width: 50%;">
# <p style="margin: 0; padding-top: 22px; text-align:right;">Tipología y ciclo de vida de los datos · PRAC1</p>
# <p style="margin: 0; text-align:right;">Máster universitario en Ciencia de datos (Data science)</p>
# <p style="margin: 0; text-align:right; padding-button: 100px;">Mario Martínez García</p>
# </div>
# </div>
# <div style="width:100%;">&nbsp;</div>

# %% [markdown]
# # Evaluación inicial.
#
# ## Wikipedia
#
# Realizaremos una evaluación inicial sobre la página general en la que realizaremos web scraping.
# El scraping se realizará sobre una página interna de la wikipedia: https://es.wikipedia.org/wiki/Tabla_peri%C3%B3dica_de_los_elementos.

# %% [markdown]
# ### 1. Archivo _robots.txt_

# %%
import requests
from bs4 import BeautifulSoup
url_page = 'https://es.wikipedia.org/robots.txt'

#Accedemos a ella y mediante beautifoul soup iremos extrayendo lo que necesitemos
page = requests.get(url_page).text 
soup = BeautifulSoup(page, "lxml")
soup
# Out:
# <html><body><p># robots.txt for http://www.wikipedia.org/ and friends
# #
# # Please note: There are a lot of pages on this site, and there are
# # some misbehaved spiders out there that go _way_ too fast. If you're
# # irresponsible, your access to the site may be blocked.
# #
#
# # Observed spamming large amounts of https://en.wikipedia.org/?curid=NNNNNN
# # and ignoring 429 ratelimit responses, claims to respect robots:
# # http://mj12bot.com/
# User-agent: MJ12bot
# Disallow: /
#
# # advertising-related bots:
# User-agent: Mediapartners-Google*
# Disallow: /
#
# # Wikipedia work bots:
# User-agent: IsraBot
# Disallow:
#
# User-agent: Orthogaffe
# Disallow:
#
# # Crawlers that are kind enough to obey, but which we'd rather not have
# # unless they're feeding search engines.
# User-agent: UbiCrawler
# Disallow: /
#
# User-agent: DOC
# Disallow: /
#
# User-agent: Zao
# Disallow: /
#
# # Some bots are known to be trouble, particularly those designed to copy
# ...

# %% [markdown]
# ### 2. Mapa del sitio web
#
# Haciendo "crtl+u" podemos visualizar el sitio web

# %% [markdown]
# ### 3. Tamaño
#
# Si sobre google buscamos 'http://www.rinconeducativo.org/' obtendremos un total de 1.020.000.000  enlaces. Nosotros no trabajaremos directamente con este enlace sino que lo haremos con el que nos redirecciona directamente sobre la tabla periódica ('https://es.wikipedia.org/wiki/Tabla_peri%C3%B3dica_de_los_elementos') por lo que la búsqueda será más eficaz.

# %% [markdown]
# ### 4. Tecnología
#
# La tecnología usada en el diseño del sitio web es la siguiente.

# %%
import builtwith
builtwith.builtwith('https://es.wikipedia.org/')
# Out:
# {'wikis': ['MediaWiki']}

# %% [markdown]
# ### 5. Propietario
#
# Importamos whois para conocer al propietario de la web.

# %%
import whois
whois.whois('https://es.wikipedia.org/')
# Out:
# {'domain_name': ['WIKIPEDIA.ORG', 'wikipedia.org'],
#  'registrar': 'MarkMonitor, Inc.',
#  'whois_server': 'whois.markmonitor.com',
#  'referral_url': None,
#  'updated_date': [datetime.datetime(2015, 12, 12, 10, 16, 19),
#   datetime.datetime(2015, 12, 12, 2, 16, 20)],
#  'creation_date': [datetime.datetime(2001, 1, 13, 0, 12, 14),
#   datetime.datetime(2001, 1, 12, 16, 12, 14)],
#  'expiration_date': [datetime.datetime(2023, 1, 13, 0, 12, 14),
#   datetime.datetime(2023, 1, 12, 0, 0)],
#  'name_servers': ['NS0.WIKIMEDIA.ORG',
#   'NS1.WIKIMEDIA.ORG',
#   'NS2.WIKIMEDIA.ORG',
#   'ns2.wikimedia.org',
#   'ns0.wikimedia.org',
#   'ns1.wikimedia.org'],
#  'status': ['clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited',
#   'clientTransferProhibited https://icann.org/epp#clientTransferProhibited',
#   'clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited',
#   'clientUpdateProhibited (https://www.icann.org/epp#clientUpdateProhibited)',
# ...
